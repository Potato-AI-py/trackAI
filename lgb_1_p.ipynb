# %%
KAGGLE = False #if getpass.getuser() == "Kaihua" else True

import os, copy, zipfile, re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from functools import reduce
from sklearn.metrics import mean_squared_error

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#!pip3 install lightgbm

# %%
import sys

DATA_PATH = ''


SEED = 2024
cat_feats = []

# %%
train_data = pd.read_parquet(os.path.join(DATA_PATH, 'track3_train.parquet'))
test_data = pd.read_parquet(os.path.join(DATA_PATH, 'track3_a.parquet'))

train_data['type'] = 'train'
test_data['type'] = 'test'
data = pd.concat([train_data, test_data], axis=0).reset_index(drop=True)
data = pd.concat([data, data['ID'].str.split('_', expand=True).rename(columns={0:'station',1:'sample',2:'time'})], axis=1)#细化向关联项

print(f'train_data: {train_data.shape}')
print(f'test_data: {test_data.shape}')
print(f'all: {data.shape}')
# Out:
# train_data: (791616, 77)
# test_data: (216384, 74)
# all: (1008000, 80)

# %%
TARGET_FEATS = ['wdir_2min', 'spd_2min', 'spd_inst_max']

# %%
# 删除有问题的目标
for item in TARGET_FEATS:
    idx = data[item] >= 199999.0
    data.loc[idx, item] = np.nan

# %%
data['time'] = data['time'].astype(int)
oldTimePos = data['time'] > 24
data.loc[oldTimePos,'time'] -=24
data['station'] = data['station'].apply(lambda x: int(x.split('D')[-1]))
cat_feats += ['station']
data['sample'] = data['sample'].apply(lambda x: int(x.split('Sample')[-1]))

# %%
feats = [item for item in data.columns if item not in TARGET_FEATS+['ID', 'sample', 'type']]#剔除不相关项
print(f'feats: {len(feats)}, {feats}')
print(cat_feats)
# Out:
# feats: 74, ['100u', '100v', '10u', '10v', '2d', '2t', 'cape', 'capes', 'cp', 'deg0l', 'lcc', 'msl', 'skt', 'sp', 'sst', 'tcc', 'd_L1000', 'q_L1000', 'r_L1000', 't_L1000', 'u_L1000', 'v_L1000', 'w_L1000', 'd_L950', 'q_L950', 'r_L950', 't_L950', 'u_L950', 'v_L950', 'w_L950', 'd_L925', 'q_L925', 'r_L925', 't_L925', 'u_L925', 'v_L925', 'w_L925', 'd_L900', 'q_L900', 'r_L900', 't_L900', 'u_L900', 'v_L900', 'w_L900', 'd_L850', 'q_L850', 'r_L850', 't_L850', 'u_L850', 'v_L850', 'w_L850', 'd_L700', 'q_L700', 'r_L700', 't_L700', 'u_L700', 'v_L700', 'w_L700', 'd_L500', 'q_L500', 'r_L500', 't_L500', 'u_L500', 'v_L500', 'w_L500', 'd_L200', 'q_L200', 'r_L200', 't_L200', 'u_L200', 'v_L200', 'w_L200', 'station', 'time']
# ['station']

# %%
data
# Out:
#                            ID  wdir_2min  spd_2min  spd_inst_max      100u  \
# 0        D0011_Sample00000_01       88.0       4.5           5.2 -3.178867
# 1        D0011_Sample00000_02      101.0       4.5           6.0 -3.044837
# 2        D0011_Sample00000_03      111.0       3.9           5.1 -2.910807
# 3        D0011_Sample00000_04      160.0       1.7           4.3 -1.870547
# 4        D0011_Sample00000_05      179.0       1.3           2.9 -0.830286
# ...                       ...        ...       ...           ...       ...
# 1007995  D0009_Sample02128_44        NaN       NaN           NaN  3.843052
# 1007996  D0009_Sample02128_45        NaN       NaN           NaN  3.674979
# 1007997  D0009_Sample02128_46        NaN       NaN           NaN  4.163034
# 1007998  D0009_Sample02128_47        NaN       NaN           NaN  4.651088
# 1007999  D0009_Sample02128_48        NaN       NaN           NaN  5.139143
#
#              100v       10u       10v        2d        2t  ...    q_L200  \
# 0        1.520631 -3.035558  0.921220 -4.296475  2.166330  ...  0.005066
# 1        1.737420 -2.924957  1.208521 -3.802847  2.137752  ...  0.005006
# 2        1.954209 -2.814357  1.495822 -3.309219  2.109175  ...  0.004946
# 3        1.442103 -1.843161  1.229792 -3.500122  1.850405  ...  0.004919
# 4        0.929998 -0.871964  0.963762 -3.691025  1.591636  ...  0.004893
# ...           ...       ...       ...       ...       ...  ...       ...
# 1007995  8.813500  3.456899  8.086399 -6.134135  4.715720  ...  0.005002
# 1007996  9.288052  3.270604  8.504519 -6.362700  5.081217  ...  0.005217
# 1007997  9.299423  3.684067  8.492985 -5.268479  5.118454  ...  0.005117
# 1007998  9.310794  4.097529  8.481452 -4.174258  5.155692  ...  0.005016
# 1007999  9.322165  4.510991  8.469918 -3.080037  5.192929  ...  0.004915
#
#            r_L200     t_L200     u_L200    v_L200    w_L200   type  station  \
# 0        7.282292 -54.574743  60.027509  4.458829  0.052047  train       11
# 1        6.950891 -54.490239  58.961815  3.799950  0.053916  train       11
# 2        6.619490 -54.405734  57.896121  3.141070  0.055785  train       11
# 3        6.931894 -54.718634  57.157805  2.129127  0.064269  train       11
# 4        7.244298 -55.031533  56.419490  1.117184  0.072752  train       11
# ...           ...        ...        ...       ...       ...    ...      ...
# 1007995  7.706795 -54.882592  58.070532 -1.666188  0.017625   test        9
# 1007996  8.115371 -54.979291  58.097675 -2.525959 -0.009414   test        9
# 1007997  7.934781 -54.952597  58.558392 -3.415087  0.020155   test        9
# 1007998  7.754191 -54.925903  59.019110 -4.304215  0.049725   test        9
# 1007999  7.573601 -54.899210  59.479827 -5.193343  0.079294   test        9
#
#          sample  time
# 0             0     1
# 1             0     2
# 2             0     3
# 3             0     4
# 4             0     5
# ...         ...   ...
# 1007995    2128    20
# 1007996    2128    21
# 1007997    2128    22
# 1007998    2128    23
# 1007999    2128    24
#
# [1008000 rows x 80 columns]

# %%
train_data = data.query('type=="train"').reset_index(drop=True)
test_data = data.query('type=="test"').reset_index(drop=True)

# %%
lgb_params = {  # 用于控制模型训练的超参数字典，如学习率、树的深度、子采样比例等
    'boosting_type': 'gbdt',
    'objective': 'quantile', #mse mape
    'metric': 'quantile',
    # 'max_depth': 6,
    'num_leaves': 2 ** 6, # 2**4
    # 'num_leaves': 31,
    'min_data_in_leaf': 20,
#     'lambda_l1': 0.5,  
#     'lambda_l2': 0.5,  
    'feature_fraction': 0.7,  
    'bagging_fraction': 0.7, 
    'bagging_freq': 5,  
    'learning_rate': 0.01,  
    'n_jobs': -1,
    'verbose': -1,
    "device_type": "cpu",
    'feature_fraction_seed':SEED,
    'bagging_seed':SEED,
    'seed': SEED,
}

# %%
# 逐小时预报采用四舍五入保留1位小数位
# 24小时内最大风由保留1位小数位的逐小时平均风速求最大值
# 24小时内极大风由保留1位小数位的逐小时极大风速求最大值

# %%
task_name = "lgb"
task_params = {"lgb": lgb_params}[task_name] # 用于控制模型训练的超参数字典，如学习率、树的深度、子采样比例等

# %%
# train_oof = {}
test_pred = {}
feats_importance = {}

for item_target in TARGET_FEATS:
    train_y = train_data[item_target]
    idx = ~train_y.isna()

    # trian_id = train_data.loc[idx, 'ID'].reset_index(drop=True)  #原始训练集中ID列+为缺失值的结果列
    train_x = train_data.loc[idx, feats].reset_index(drop=True)  #训练集（已细化并剔除不相关）+为缺失值的结果列
    testA_x = test_data[feats].reset_index(drop=True) #测试集（已细化并剔除不相关）
    train_y = train_y.loc[idx].reset_index(drop=True) #缺失值的结果列
    group_x = train_data.loc[idx, 'sample'].reset_index(drop=True) #原始训练集中sample列+为缺失值的结果列
    print(train_x.shape, testA_x.shape)

    # item_oof = np.zeros(train_x.shape[0])
    item_pred = np.zeros(testA_x.shape[0])

    fold_num = 6
    item_importance = 0
    from sklearn.model_selection import GroupKFold #用于分组数据的交叉验证迭代器 测试模型的泛化能力 检测过拟合情况
    import lightgbm as lgb #轻量级梯度提升  基于学习算法的决策树  分布式、高效
    kf = GroupKFold(n_splits=fold_num, ) #n_splits一般3-10之间  数据集越大n_splits调小  越大越精准但泛化能力下降过拟合增大   需要找平衡点
    for fold, (train_idx, val_idx) in enumerate(kf.split(train_x, groups=group_x)): #基于GroupKFold交叉验证分组，根据sample标识（文件夹）分组  保证每个分组样本均匀分配到不同训练集和验证集中
        print('-----------', fold)
        train = lgb.Dataset(   # 数据集封装成一个对象、加载入内存 方便LightGBM 进行训练和预测
            train_x.loc[train_idx], #训练集
            train_y.loc[train_idx],
            categorical_feature=cat_feats # 类别特征列表，用于指定数据集中哪些特征是类别型的特征
        )
        val = lgb.Dataset(
            train_x.loc[val_idx], #验证集
            train_y.loc[val_idx],
            categorical_feature=cat_feats # cat_feats=['station']
        )
        model = lgb.train(task_params, train, valid_sets=[train, val], num_boost_round=90_000,
                            callbacks=[lgb.early_stopping(100), lgb.log_evaluation(100)])
        #valid_sets 验证数据集为什么还要加上train
        """
        params: 用于控制模型训练的超参数字典，如学习率、树的深度、子采样比例等。
        train_set: 训练数据集，可以是 lgb.Dataset 对象或数据矩阵。
        num_boost_round: 迭代次数，即弱分类器的数量。
        valid_sets: 验证数据集，可以是一个 lgb.Dataset 对象或一个列表，其中每个元素都是 lgb.Dataset 对象。
        early_stopping_rounds: 早停次数，如果在连续的 early_stopping_rounds 次迭代中验证集的损失没有得到改善，则停止迭代。
            lgb.early_stopping()比这个好用，可以把num_boost_round放的很大，他可以智能判断早停
        callbacks: 回调函数列表，用于在训练过程中执行特定操作，如打印日志、保存模型等。
        """
        # item_oof[val_idx] += (model.predict(train_x.loc[val_idx])) #预测验证集结果存入item_oof

        item_pred += (model.predict(testA_x))/fold_num  #预测测试集/折数=平局值 item_pred
        item_importance += model.feature_importance(importance_type='gain') / fold_num # 特征性/折数=平均值 importance_type=split/gain 分别表示特征被用于分裂的次数和特征对模型的贡献度

    importance = pd.DataFrame()
    importance['name'] = feats
    importance['importance'] = item_importance

    # train_oof[item_target] = pd.DataFrame({"ID": trian_id, f"{item_target}_true": train_y, f"{item_target}_pred": item_oof}) #重构预测的验证集结果列
    test_pred[item_target] = pd.DataFrame({"ID": test_data['ID'], f"{item_target}": item_pred})
    feats_importance[item_target] = importance #重构预测的测试集结果列
# Out:
# (770742, 74) (216384, 74)
# ----------- 0
# Training until validation scores don't improve for 100 rounds
# [100]	training's quantile: 12.3114	valid_1's quantile: 11.7059
# [200]	training's quantile: 10.7351	valid_1's quantile: 10.2694
# [300]	training's quantile: 10.0007	valid_1's quantile: 9.60592
# [400]	training's quantile: 9.64094	valid_1's quantile: 9.31093
# [500]	training's quantile: 9.4417	valid_1's quantile: 9.16613
# [600]	training's quantile: 9.31385	valid_1's quantile: 9.08326
# [700]	training's quantile: 9.22451	valid_1's quantile: 9.03306
# [800]	training's quantile: 9.15514	valid_1's quantile: 8.99445
# [900]	training's quantile: 9.095	valid_1's quantile: 8.96311
# [1000]	training's quantile: 9.0449	valid_1's quantile: 8.93699
# [1100]	training's quantile: 8.9992	valid_1's quantile: 8.91366
# [1200]	training's quantile: 8.95432	valid_1's quantile: 8.88992
# [1300]	training's quantile: 8.91358	valid_1's quantile: 8.87037
# [1400]	training's quantile: 8.86752	valid_1's quantile: 8.84703
# [1500]	training's quantile: 8.8303	valid_1's quantile: 8.82708
# [1600]	training's quantile: 8.79728	valid_1's quantile: 8.80905
# [1700]	training's quantile: 8.7633	valid_1's quantile: 8.79258
# [1800]	training's quantile: 8.72185	valid_1's quantile: 8.77361
# [1900]	training's quantile: 8.68957	valid_1's quantile: 8.75679
# [2000]	training's quantile: 8.65971	valid_1's quantile: 8.74207
# [2100]	training's quantile: 8.62729	valid_1's quantile: 8.72528
# [2200]	training's quantile: 8.5966	valid_1's quantile: 8.71169
# [2300]	training's quantile: 8.56809	valid_1's quantile: 8.69725
# [2400]	training's quantile: 8.5411	valid_1's quantile: 8.68693
# [2500]	training's quantile: 8.5141	valid_1's quantile: 8.67613
# [2600]	training's quantile: 8.48813	valid_1's quantile: 8.66514
# [2700]	training's quantile: 8.46577	valid_1's quantile: 8.658
# [2800]	training's quantile: 8.44101	valid_1's quantile: 8.64843
# [2900]	training's quantile: 8.41595	valid_1's quantile: 8.63725
# [3000]	training's quantile: 8.39036	valid_1's quantile: 8.62693
# [3100]	training's quantile: 8.36538	valid_1's quantile: 8.61539
# [3200]	training's quantile: 8.34327	valid_1's quantile: 8.60706
# [3300]	training's quantile: 8.3222	valid_1's quantile: 8.599
# [3400]	training's quantile: 8.30274	valid_1's quantile: 8.59143
# [3500]	training's quantile: 8.28216	valid_1's quantile: 8.58327
# [3600]	training's quantile: 8.26208	valid_1's quantile: 8.57506
# [3700]	training's quantile: 8.24461	valid_1's quantile: 8.56938
# [3800]	training's quantile: 8.22393	valid_1's quantile: 8.56144
# [3900]	training's quantile: 8.20661	valid_1's quantile: 8.55466
# [4000]	training's quantile: 8.18918	valid_1's quantile: 8.5489
# [4100]	training's quantile: 8.17054	valid_1's quantile: 8.54135
# [4200]	training's quantile: 8.15041	valid_1's quantile: 8.53226
# [4300]	training's quantile: 8.13288	valid_1's quantile: 8.52575
# [4400]	training's quantile: 8.11332	valid_1's quantile: 8.51816
# [4500]	training's quantile: 8.09351	valid_1's quantile: 8.51086
# [4600]	training's quantile: 8.07589	valid_1's quantile: 8.50498
# [4700]	training's quantile: 8.06088	valid_1's quantile: 8.49919
# [4800]	training's quantile: 8.04433	valid_1's quantile: 8.49256
# [4900]	training's quantile: 8.02785	valid_1's quantile: 8.48717
# [5000]	training's quantile: 8.01145	valid_1's quantile: 8.48223
# [5100]	training's quantile: 7.99648	valid_1's quantile: 8.47624
# [5200]	training's quantile: 7.97989	valid_1's quantile: 8.46833
# [5300]	training's quantile: 7.96485	valid_1's quantile: 8.46293
# [5400]	training's quantile: 7.94912	valid_1's quantile: 8.4569
# [5500]	training's quantile: 7.9332	valid_1's quantile: 8.45236
# [5600]	training's quantile: 7.91789	valid_1's quantile: 8.44695
# [5700]	training's quantile: 7.9011	valid_1's quantile: 8.44125
# [5800]	training's quantile: 7.88526	valid_1's quantile: 8.43478
# [5900]	training's quantile: 7.87243	valid_1's quantile: 8.43039
# [6000]	training's quantile: 7.85727	valid_1's quantile: 8.42495
# [6100]	training's quantile: 7.84274	valid_1's quantile: 8.41993
# [6200]	training's quantile: 7.82839	valid_1's quantile: 8.4134
# [6300]	training's quantile: 7.81355	valid_1's quantile: 8.40739
# [6400]	training's quantile: 7.79457	valid_1's quantile: 8.39831
# [6500]	training's quantile: 7.77689	valid_1's quantile: 8.39061
# [6600]	training's quantile: 7.76177	valid_1's quantile: 8.38468
# [6700]	training's quantile: 7.74798	valid_1's quantile: 8.37936
# [6800]	training's quantile: 7.73621	valid_1's quantile: 8.37443
# [6900]	training's quantile: 7.72445	valid_1's quantile: 8.36949
# [7000]	training's quantile: 7.71095	valid_1's quantile: 8.36305
# [7100]	training's quantile: 7.69796	valid_1's quantile: 8.35734
# [7200]	training's quantile: 7.68365	valid_1's quantile: 8.35168
# [7300]	training's quantile: 7.67277	valid_1's quantile: 8.3479
# [7400]	training's quantile: 7.6601	valid_1's quantile: 8.34228
# [7500]	training's quantile: 7.64726	valid_1's quantile: 8.33686
# [7600]	training's quantile: 7.6343	valid_1's quantile: 8.33273
# [7700]	training's quantile: 7.62101	valid_1's quantile: 8.32764
# [7800]	training's quantile: 7.60976	valid_1's quantile: 8.32356
# [7900]	training's quantile: 7.60016	valid_1's quantile: 8.32037
# [8000]	training's quantile: 7.59084	valid_1's quantile: 8.31755
# [8100]	training's quantile: 7.58012	valid_1's quantile: 8.31412
# [8200]	training's quantile: 7.56959	valid_1's quantile: 8.3106
# [8300]	training's quantile: 7.559	valid_1's quantile: 8.30631
# [8400]	training's quantile: 7.54915	valid_1's quantile: 8.30292
# [8500]	training's quantile: 7.53887	valid_1's quantile: 8.30017
# [8600]	training's quantile: 7.52864	valid_1's quantile: 8.2967
# [8700]	training's quantile: 7.51801	valid_1's quantile: 8.29225
# [8800]	training's quantile: 7.5085	valid_1's quantile: 8.2889
# [8900]	training's quantile: 7.4991	valid_1's quantile: 8.2852
# [9000]	training's quantile: 7.48863	valid_1's quantile: 8.28226
# [9100]	training's quantile: 7.47896	valid_1's quantile: 8.27859
# [9200]	training's quantile: 7.46824	valid_1's quantile: 8.27468
# [9300]	training's quantile: 7.45746	valid_1's quantile: 8.27121
# [9400]	training's quantile: 7.44704	valid_1's quantile: 8.26783
# [9500]	training's quantile: 7.43908	valid_1's quantile: 8.2651
# [9600]	training's quantile: 7.43048	valid_1's quantile: 8.26362
# [9700]	training's quantile: 7.42222	valid_1's quantile: 8.26088
# [9800]	training's quantile: 7.4136	valid_1's quantile: 8.25782
# [9900]	training's quantile: 7.40582	valid_1's quantile: 8.25583
# [10000]	training's quantile: 7.39751	valid_1's quantile: 8.25215
# [10100]	training's quantile: 7.3888	valid_1's quantile: 8.24945
# [10200]	training's quantile: 7.37847	valid_1's quantile: 8.24588
# [10300]	training's quantile: 7.37009	valid_1's quantile: 8.24299
# [10400]	training's quantile: 7.36238	valid_1's quantile: 8.24123
# [10500]	training's quantile: 7.35528	valid_1's quantile: 8.24005
# [10600]	training's quantile: 7.34625	valid_1's quantile: 8.23701
# [10700]	training's quantile: 7.33604	valid_1's quantile: 8.23328
# [10800]	training's quantile: 7.3286	valid_1's quantile: 8.23104
# [10900]	training's quantile: 7.32139	valid_1's quantile: 8.22923
# [11000]	training's quantile: 7.31398	valid_1's quantile: 8.22712
# [11100]	training's quantile: 7.30615	valid_1's quantile: 8.22518
# [11200]	training's quantile: 7.29746	valid_1's quantile: 8.22251
# [11300]	training's quantile: 7.29037	valid_1's quantile: 8.22067
# [11400]	training's quantile: 7.28267	valid_1's quantile: 8.21896
# [11500]	training's quantile: 7.27467	valid_1's quantile: 8.2167
# [11600]	training's quantile: 7.26809	valid_1's quantile: 8.21569
# [11700]	training's quantile: 7.26023	valid_1's quantile: 8.21297
# [11800]	training's quantile: 7.25284	valid_1's quantile: 8.21074
# [11900]	training's quantile: 7.24527	valid_1's quantile: 8.20908
# [12000]	training's quantile: 7.23658	valid_1's quantile: 8.20696
# [12100]	training's quantile: 7.22909	valid_1's quantile: 8.20479
# [12200]	training's quantile: 7.22127	valid_1's quantile: 8.20296
# [12300]	training's quantile: 7.21409	valid_1's quantile: 8.20092
# [12400]	training's quantile: 7.2066	valid_1's quantile: 8.1997
# [12500]	training's quantile: 7.19869	valid_1's quantile: 8.19724
# [12600]	training's quantile: 7.19208	valid_1's quantile: 8.19582
# [12700]	training's quantile: 7.18493	valid_1's quantile: 8.19422
# [12800]	training's quantile: 7.17778	valid_1's quantile: 8.19267
# [12900]	training's quantile: 7.16989	valid_1's quantile: 8.19028
# [13000]	training's quantile: 7.16198	valid_1's quantile: 8.18769
# [13100]	training's quantile: 7.15462	valid_1's quantile: 8.18636
# [13200]	training's quantile: 7.14788	valid_1's quantile: 8.18493
# [13300]	training's quantile: 7.14105	valid_1's quantile: 8.18292
# [13400]	training's quantile: 7.13425	valid_1's quantile: 8.18145
# [13500]	training's quantile: 7.12792	valid_1's quantile: 8.18005
# [13600]	training's quantile: 7.12154	valid_1's quantile: 8.17826
# [13700]	training's quantile: 7.11537	valid_1's quantile: 8.1771
# [13800]	training's quantile: 7.10865	valid_1's quantile: 8.1752
# [13900]	training's quantile: 7.10195	valid_1's quantile: 8.17384
# [14000]	training's quantile: 7.09576	valid_1's quantile: 8.17202
# [14100]	training's quantile: 7.08875	valid_1's quantile: 8.16888
# [14200]	training's quantile: 7.08226	valid_1's quantile: 8.16742
# [14300]	training's quantile: 7.07519	valid_1's quantile: 8.16561
# [14400]	training's quantile: 7.06825	valid_1's quantile: 8.16331
# [14500]	training's quantile: 7.06179	valid_1's quantile: 8.16128
# [14600]	training's quantile: 7.05522	valid_1's quantile: 8.15906
# [14700]	training's quantile: 7.04964	valid_1's quantile: 8.15787
# [14800]	training's quantile: 7.04294	valid_1's quantile: 8.15629
# [14900]	training's quantile: 7.03708	valid_1's quantile: 8.15504
# [15000]	training's quantile: 7.03103	valid_1's quantile: 8.1535
# [15100]	training's quantile: 7.02495	valid_1's quantile: 8.15272
# [15200]	training's quantile: 7.01734	valid_1's quantile: 8.15002
# [15300]	training's quantile: 7.01105	valid_1's quantile: 8.14795
# [15400]	training's quantile: 7.0057	valid_1's quantile: 8.14688
# [15500]	training's quantile: 6.99892	valid_1's quantile: 8.14486
# [15600]	training's quantile: 6.99321	valid_1's quantile: 8.14353
# [15700]	training's quantile: 6.98799	valid_1's quantile: 8.14271
# [15800]	training's quantile: 6.98222	valid_1's quantile: 8.14147
# [15900]	training's quantile: 6.97614	valid_1's quantile: 8.14019
# [16000]	training's quantile: 6.97062	valid_1's quantile: 8.13891
# [16100]	training's quantile: 6.96362	valid_1's quantile: 8.13718
# [16200]	training's quantile: 6.95786	valid_1's quantile: 8.13558
# [16300]	training's quantile: 6.95245	valid_1's quantile: 8.13442
# [16400]	training's quantile: 6.94746	valid_1's quantile: 8.1334
# [16500]	training's quantile: 6.94138	valid_1's quantile: 8.13172
# [16600]	training's quantile: 6.93584	valid_1's quantile: 8.1302
# [16700]	training's quantile: 6.93025	valid_1's quantile: 8.12887
# [16800]	training's quantile: 6.92459	valid_1's quantile: 8.12738
# [16900]	training's quantile: 6.91947	valid_1's quantile: 8.12664
# [17000]	training's quantile: 6.91432	valid_1's quantile: 8.12548
# [17100]	training's quantile: 6.90869	valid_1's quantile: 8.1247
# [17200]	training's quantile: 6.90331	valid_1's quantile: 8.12372
# [17300]	training's quantile: 6.89746	valid_1's quantile: 8.12274
# [17400]	training's quantile: 6.89184	valid_1's quantile: 8.12141
# [17500]	training's quantile: 6.88702	valid_1's quantile: 8.12048
# [17600]	training's quantile: 6.88192	valid_1's quantile: 8.11905
# [17700]	training's quantile: 6.87488	valid_1's quantile: 8.11711
# [17800]	training's quantile: 6.86859	valid_1's quantile: 8.11546
# [17900]	training's quantile: 6.86321	valid_1's quantile: 8.11402
# [18000]	training's quantile: 6.85739	valid_1's quantile: 8.11214
# [18100]	training's quantile: 6.85235	valid_1's quantile: 8.11082
# [18200]	training's quantile: 6.84674	valid_1's quantile: 8.1096
# [18300]	training's quantile: 6.84089	valid_1's quantile: 8.10829
# [18400]	training's quantile: 6.83566	valid_1's quantile: 8.10748
# [18500]	training's quantile: 6.83022	valid_1's quantile: 8.10582
# [18600]	training's quantile: 6.8247	valid_1's quantile: 8.10451
# [18700]	training's quantile: 6.81966	valid_1's quantile: 8.10305
# [18800]	training's quantile: 6.81475	valid_1's quantile: 8.1024
# [18900]	training's quantile: 6.81019	valid_1's quantile: 8.10081
# [19000]	training's quantile: 6.80509	valid_1's quantile: 8.10015
# [19100]	training's quantile: 6.80057	valid_1's quantile: 8.09939
# [19200]	training's quantile: 6.79615	valid_1's quantile: 8.09849
# [19300]	training's quantile: 6.79073	valid_1's quantile: 8.09762
# [19400]	training's quantile: 6.78519	valid_1's quantile: 8.09642
# [19500]	training's quantile: 6.77974	valid_1's quantile: 8.09545
# [19600]	training's quantile: 6.77384	valid_1's quantile: 8.09426
# [19700]	training's quantile: 6.76819	valid_1's quantile: 8.09271
# [19800]	training's quantile: 6.76268	valid_1's quantile: 8.09152
# [19900]	training's quantile: 6.75809	valid_1's quantile: 8.09067
# [20000]	training's quantile: 6.75315	valid_1's quantile: 8.08961
# [20100]	training's quantile: 6.74853	valid_1's quantile: 8.08854
# [20200]	training's quantile: 6.74402	valid_1's quantile: 8.08689
# [20300]	training's quantile: 6.73981	valid_1's quantile: 8.08603
# [20400]	training's quantile: 6.73454	valid_1's quantile: 8.08468
# [20500]	training's quantile: 6.72988	valid_1's quantile: 8.08353
# [20600]	training's quantile: 6.72502	valid_1's quantile: 8.08225
# [20700]	training's quantile: 6.71848	valid_1's quantile: 8.08011
# [20800]	training's quantile: 6.71413	valid_1's quantile: 8.07901
# [20900]	training's quantile: 6.7088	valid_1's quantile: 8.07749
# [21000]	training's quantile: 6.70445	valid_1's quantile: 8.07648
# [21100]	training's quantile: 6.70022	valid_1's quantile: 8.07553
# [21200]	training's quantile: 6.69619	valid_1's quantile: 8.07478
# [21300]	training's quantile: 6.69285	valid_1's quantile: 8.07398
# [21400]	training's quantile: 6.68919	valid_1's quantile: 8.07292
# [21500]	training's quantile: 6.6856	valid_1's quantile: 8.0721
# [21600]	training's quantile: 6.68185	valid_1's quantile: 8.07144
# [21700]	training's quantile: 6.67772	valid_1's quantile: 8.07028
# [21800]	training's quantile: 6.67393	valid_1's quantile: 8.06952
# [21900]	training's quantile: 6.66998	valid_1's quantile: 8.06871
# [22000]	training's quantile: 6.66563	valid_1's quantile: 8.06708
# [22100]	training's quantile: 6.66146	valid_1's quantile: 8.06629
# [22200]	training's quantile: 6.65799	valid_1's quantile: 8.06602
# [22300]	training's quantile: 6.65409	valid_1's quantile: 8.06532
# [22400]	training's quantile: 6.64952	valid_1's quantile: 8.06439
# [22500]	training's quantile: 6.64495	valid_1's quantile: 8.06328
# [22600]	training's quantile: 6.64103	valid_1's quantile: 8.06266
# [22700]	training's quantile: 6.63667	valid_1's quantile: 8.06107
# [22800]	training's quantile: 6.63293	valid_1's quantile: 8.06082
# [22900]	training's quantile: 6.629	valid_1's quantile: 8.06025
# [23000]	training's quantile: 6.62507	valid_1's quantile: 8.05984
# [23100]	training's quantile: 6.62133	valid_1's quantile: 8.05888
# [23200]	training's quantile: 6.61715	valid_1's quantile: 8.05817
# [23300]	training's quantile: 6.6123	valid_1's quantile: 8.05661
# [23400]	training's quantile: 6.60732	valid_1's quantile: 8.05476
# [23500]	training's quantile: 6.60341	valid_1's quantile: 8.05391
# [23600]	training's quantile: 6.5985	valid_1's quantile: 8.05221
# [23700]	training's quantile: 6.59447	valid_1's quantile: 8.05145
# [23800]	training's quantile: 6.59057	valid_1's quantile: 8.05092
# [23900]	training's quantile: 6.5863	valid_1's quantile: 8.05005
# [24000]	training's quantile: 6.58162	valid_1's quantile: 8.048
# [24100]	training's quantile: 6.57732	valid_1's quantile: 8.04693
# [24200]	training's quantile: 6.57425	valid_1's quantile: 8.0463
# [24300]	training's quantile: 6.57118	valid_1's quantile: 8.04557
# [24400]	training's quantile: 6.56798	valid_1's quantile: 8.04525
# [24500]	training's quantile: 6.56382	valid_1's quantile: 8.04413
# [24600]	training's quantile: 6.55977	valid_1's quantile: 8.04347
# [24700]	training's quantile: 6.55587	valid_1's quantile: 8.04239
# [24800]	training's quantile: 6.55109	valid_1's quantile: 8.04139
# [24900]	training's quantile: 6.54751	valid_1's quantile: 8.04076
# [25000]	training's quantile: 6.54386	valid_1's quantile: 8.03995
# [25100]	training's quantile: 6.5399	valid_1's quantile: 8.03913
# [25200]	training's quantile: 6.53619	valid_1's quantile: 8.03831
# [25300]	training's quantile: 6.53308	valid_1's quantile: 8.03805
# [25400]	training's quantile: 6.52982	valid_1's quantile: 8.03733
# [25500]	training's quantile: 6.52673	valid_1's quantile: 8.03675
# [25600]	training's quantile: 6.52319	valid_1's quantile: 8.03633
# [25700]	training's quantile: 6.51916	valid_1's quantile: 8.03533
# [25800]	training's quantile: 6.51508	valid_1's quantile: 8.03423
# [25900]	training's quantile: 6.51089	valid_1's quantile: 8.03335
# [26000]	training's quantile: 6.50669	valid_1's quantile: 8.03255
# [26100]	training's quantile: 6.50284	valid_1's quantile: 8.0319
# [26200]	training's quantile: 6.49952	valid_1's quantile: 8.03111
# [26300]	training's quantile: 6.49601	valid_1's quantile: 8.03052
# [26400]	training's quantile: 6.49192	valid_1's quantile: 8.02944
# [26500]	training's quantile: 6.48787	valid_1's quantile: 8.02882
# [26600]	training's quantile: 6.48456	valid_1's quantile: 8.02826
# [26700]	training's quantile: 6.48138	valid_1's quantile: 8.02773
# [26800]	training's quantile: 6.47738	valid_1's quantile: 8.0268
# [26900]	training's quantile: 6.47311	valid_1's quantile: 8.02602
# [27000]	training's quantile: 6.46963	valid_1's quantile: 8.02539
# [27100]	training's quantile: 6.46571	valid_1's quantile: 8.0247
# [27200]	training's quantile: 6.46187	valid_1's quantile: 8.02385
# [27300]	training's quantile: 6.45813	valid_1's quantile: 8.02283
# [27400]	training's quantile: 6.45445	valid_1's quantile: 8.02211
# [27500]	training's quantile: 6.45119	valid_1's quantile: 8.02161
# [27600]	training's quantile: 6.44787	valid_1's quantile: 8.02098
# [27700]	training's quantile: 6.44446	valid_1's quantile: 8.02038
# [27800]	training's quantile: 6.4413	valid_1's quantile: 8.01975
# [27900]	training's quantile: 6.43811	valid_1's quantile: 8.01897
# [28000]	training's quantile: 6.43469	valid_1's quantile: 8.01823
# [28100]	training's quantile: 6.4311	valid_1's quantile: 8.01744
# [28200]	training's quantile: 6.4282	valid_1's quantile: 8.01712
# [28300]	training's quantile: 6.42526	valid_1's quantile: 8.01671
# [28400]	training's quantile: 6.42246	valid_1's quantile: 8.01636
# [28500]	training's quantile: 6.41949	valid_1's quantile: 8.0157
# [28600]	training's quantile: 6.41627	valid_1's quantile: 8.01551
# [28700]	training's quantile: 6.41324	valid_1's quantile: 8.01526
# [28800]	training's quantile: 6.40988	valid_1's quantile: 8.01482
# [28900]	training's quantile: 6.40635	valid_1's quantile: 8.01375
# [29000]	training's quantile: 6.40335	valid_1's quantile: 8.01286
# [29100]	training's quantile: 6.40058	valid_1's quantile: 8.01222
# [29200]	training's quantile: 6.39778	valid_1's quantile: 8.0117
# [29300]	training's quantile: 6.39475	valid_1's quantile: 8.011
# [29400]	training's quantile: 6.3915	valid_1's quantile: 8.01024
# [29500]	training's quantile: 6.38833	valid_1's quantile: 8.0099
# [29600]	training's quantile: 6.38469	valid_1's quantile: 8.00902
# [29700]	training's quantile: 6.38188	valid_1's quantile: 8.00828
# [29800]	training's quantile: 6.37871	valid_1's quantile: 8.00756
# [29900]	training's quantile: 6.3753	valid_1's quantile: 8.00693
# [30000]	training's quantile: 6.37246	valid_1's quantile: 8.00642
# [30100]	training's quantile: 6.36958	valid_1's quantile: 8.00583
# [30200]	training's quantile: 6.36691	valid_1's quantile: 8.0054
# [30300]	training's quantile: 6.36391	valid_1's quantile: 8.00507
# [30400]	training's quantile: 6.36153	valid_1's quantile: 8.00472
# [30500]	training's quantile: 6.35886	valid_1's quantile: 8.00454
# [30600]	training's quantile: 6.35606	valid_1's quantile: 8.00415
# [30700]	training's quantile: 6.35355	valid_1's quantile: 8.00379
# [30800]	training's quantile: 6.3504	valid_1's quantile: 8.00327
# [30900]	training's quantile: 6.34721	valid_1's quantile: 8.00243
# [31000]	training's quantile: 6.34459	valid_1's quantile: 8.00204
# [31100]	training's quantile: 6.34202	valid_1's quantile: 8.00176
# [31200]	training's quantile: 6.33907	valid_1's quantile: 8.00147
# [31300]	training's quantile: 6.33607	valid_1's quantile: 8.00097
# [31400]	training's quantile: 6.33351	valid_1's quantile: 8.00054
# [31500]	training's quantile: 6.33091	valid_1's quantile: 8.00039
# [31600]	training's quantile: 6.3285	valid_1's quantile: 8.00006
# [31700]	training's quantile: 6.32568	valid_1's quantile: 7.99965
# [31800]	training's quantile: 6.32274	valid_1's quantile: 7.99948
# [31900]	training's quantile: 6.32011	valid_1's quantile: 7.99865
# [32000]	training's quantile: 6.31768	valid_1's quantile: 7.99823
# [32100]	training's quantile: 6.31499	valid_1's quantile: 7.99753
# [32200]	training's quantile: 6.31198	valid_1's quantile: 7.99698
# [32300]	training's quantile: 6.30933	valid_1's quantile: 7.99684
# [32400]	training's quantile: 6.30691	valid_1's quantile: 7.99673
# Early stopping, best iteration is:
# [32323]	training's quantile: 6.30858	valid_1's quantile: 7.9966
# ----------- 1
# Training until validation scores don't improve for 100 rounds
# [100]	training's quantile: 12.3001	valid_1's quantile: 11.7974
# [200]	training's quantile: 10.6976	valid_1's quantile: 10.4318
# [300]	training's quantile: 9.96443	valid_1's quantile: 9.88646
# [400]	training's quantile: 9.60787	valid_1's quantile: 9.63978
# [500]	training's quantile: 9.40868	valid_1's quantile: 9.49883
# [600]	training's quantile: 9.28181	valid_1's quantile: 9.41589
# [700]	training's quantile: 9.19801	valid_1's quantile: 9.36194
# [800]	training's quantile: 9.12494	valid_1's quantile: 9.32049
# [900]	training's quantile: 9.06322	valid_1's quantile: 9.2862
# [1000]	training's quantile: 9.01267	valid_1's quantile: 9.25909
# [1100]	training's quantile: 8.96678	valid_1's quantile: 9.23294
# [1200]	training's quantile: 8.92387	valid_1's quantile: 9.20942
# [1300]	training's quantile: 8.88536	valid_1's quantile: 9.18694
# [1400]	training's quantile: 8.84201	valid_1's quantile: 9.16422
# [1500]	training's quantile: 8.80495	valid_1's quantile: 9.14402
# [1600]	training's quantile: 8.76814	valid_1's quantile: 9.1254
# [1700]	training's quantile: 8.7431	valid_1's quantile: 9.11493
# [1800]	training's quantile: 8.71253	valid_1's quantile: 9.09838
# [1900]	training's quantile: 8.68189	valid_1's quantile: 9.08476
# [2000]	training's quantile: 8.65348	valid_1's quantile: 9.0685
# [2100]	training's quantile: 8.62448	valid_1's quantile: 9.05211
# [2200]	training's quantile: 8.5961	valid_1's quantile: 9.03883
# [2300]	training's quantile: 8.56859	valid_1's quantile: 9.02483
# [2400]	training's quantile: 8.54026	valid_1's quantile: 9.00895
# [2500]	training's quantile: 8.51097	valid_1's quantile: 8.99561
# [2600]	training's quantile: 8.48418	valid_1's quantile: 8.9836
# [2700]	training's quantile: 8.4566	valid_1's quantile: 8.96876
# [2800]	training's quantile: 8.42686	valid_1's quantile: 8.95496
# [2900]	training's quantile: 8.3985	valid_1's quantile: 8.94188
# [3000]	training's quantile: 8.37622	valid_1's quantile: 8.92971
# [3100]	training's quantile: 8.35397	valid_1's quantile: 8.92055
# [3200]	training's quantile: 8.33328	valid_1's quantile: 8.91117
# [3300]	training's quantile: 8.31385	valid_1's quantile: 8.90412
# [3400]	training's quantile: 8.29577	valid_1's quantile: 8.89659
# [3500]	training's quantile: 8.27515	valid_1's quantile: 8.88539
# [3600]	training's quantile: 8.25411	valid_1's quantile: 8.87728
# [3700]	training's quantile: 8.23523	valid_1's quantile: 8.86953
# [3800]	training's quantile: 8.21825	valid_1's quantile: 8.86393
# [3900]	training's quantile: 8.19989	valid_1's quantile: 8.85645
# [4000]	training's quantile: 8.18038	valid_1's quantile: 8.85025
# [4100]	training's quantile: 8.16163	valid_1's quantile: 8.84378
# [4200]	training's quantile: 8.1436	valid_1's quantile: 8.83704
# [4300]	training's quantile: 8.12684	valid_1's quantile: 8.83041
# [4400]	training's quantile: 8.10995	valid_1's quantile: 8.82336
# [4500]	training's quantile: 8.09351	valid_1's quantile: 8.81747
# [4600]	training's quantile: 8.07808	valid_1's quantile: 8.81168
# [4700]	training's quantile: 8.06133	valid_1's quantile: 8.80484
# [4800]	training's quantile: 8.04689	valid_1's quantile: 8.79997
# [4900]	training's quantile: 8.03281	valid_1's quantile: 8.79374
# [5000]	training's quantile: 8.01713	valid_1's quantile: 8.78622
# [5100]	training's quantile: 7.99804	valid_1's quantile: 8.77622
# [5200]	training's quantile: 7.98382	valid_1's quantile: 8.76816
# [5300]	training's quantile: 7.96796	valid_1's quantile: 8.76011
# [5400]	training's quantile: 7.95347	valid_1's quantile: 8.75111
# [5500]	training's quantile: 7.93988	valid_1's quantile: 8.74446
# [5600]	training's quantile: 7.92562	valid_1's quantile: 8.73921
# [5700]	training's quantile: 7.91141	valid_1's quantile: 8.73335
# [5800]	training's quantile: 7.89617	valid_1's quantile: 8.72638
# [5900]	training's quantile: 7.88081	valid_1's quantile: 8.71955
# [6000]	training's quantile: 7.86607	valid_1's quantile: 8.71398
# [6100]	training's quantile: 7.85219	valid_1's quantile: 8.70935
# [6200]	training's quantile: 7.83597	valid_1's quantile: 8.70468
# [6300]	training's quantile: 7.81994	valid_1's quantile: 8.69742
# [6400]	training's quantile: 7.80471	valid_1's quantile: 8.69307
# [6500]	training's quantile: 7.78914	valid_1's quantile: 8.68716
# [6600]	training's quantile: 7.77444	valid_1's quantile: 8.68117
# [6700]	training's quantile: 7.75961	valid_1's quantile: 8.67447
# [6800]	training's quantile: 7.74655	valid_1's quantile: 8.66958
# [6900]	training's quantile: 7.7325	valid_1's quantile: 8.66474
# [7000]	training's quantile: 7.72068	valid_1's quantile: 8.66116
# [7100]	training's quantile: 7.70496	valid_1's quantile: 8.65422
# [7200]	training's quantile: 7.6924	valid_1's quantile: 8.65055
# [7300]	training's quantile: 7.67872	valid_1's quantile: 8.64434
# [7400]	training's quantile: 7.66734	valid_1's quantile: 8.64032
# [7500]	training's quantile: 7.65587	valid_1's quantile: 8.63639
# [7600]	training's quantile: 7.64498	valid_1's quantile: 8.63294
# [7700]	training's quantile: 7.63274	valid_1's quantile: 8.62867
# [7800]	training's quantile: 7.62322	valid_1's quantile: 8.62643
# [7900]	training's quantile: 7.61339	valid_1's quantile: 8.62363
# [8000]	training's quantile: 7.6011	valid_1's quantile: 8.6198
# [8100]	training's quantile: 7.58958	valid_1's quantile: 8.61597
# [8200]	training's quantile: 7.57817	valid_1's quantile: 8.61277
# [8300]	training's quantile: 7.56728	valid_1's quantile: 8.60918
# [8400]	training's quantile: 7.55479	valid_1's quantile: 8.60378
# [8500]	training's quantile: 7.54001	valid_1's quantile: 8.59794
# [8600]	training's quantile: 7.52739	valid_1's quantile: 8.59311
# [8700]	training's quantile: 7.51483	valid_1's quantile: 8.58696
# [8800]	training's quantile: 7.50396	valid_1's quantile: 8.58291
# [8900]	training's quantile: 7.49456	valid_1's quantile: 8.57989
# [9000]	training's quantile: 7.48436	valid_1's quantile: 8.5767
# [9100]	training's quantile: 7.47519	valid_1's quantile: 8.57404
# [9200]	training's quantile: 7.46557	valid_1's quantile: 8.57138
# [9300]	training's quantile: 7.45668	valid_1's quantile: 8.5686
# [9400]	training's quantile: 7.4475	valid_1's quantile: 8.56537
# [9500]	training's quantile: 7.43874	valid_1's quantile: 8.56291
# [9600]	training's quantile: 7.43027	valid_1's quantile: 8.56098
# [9700]	training's quantile: 7.42162	valid_1's quantile: 8.55817
# [9800]	training's quantile: 7.41383	valid_1's quantile: 8.55628
# [9900]	training's quantile: 7.4043	valid_1's quantile: 8.55298
# [10000]	training's quantile: 7.39377	valid_1's quantile: 8.54955
# [10100]	training's quantile: 7.38558	valid_1's quantile: 8.5481
# [10200]	training's quantile: 7.37576	valid_1's quantile: 8.54503
# [10300]	training's quantile: 7.36519	valid_1's quantile: 8.54107
# [10400]	training's quantile: 7.35308	valid_1's quantile: 8.53766
# [10500]	training's quantile: 7.34445	valid_1's quantile: 8.53496
# [10600]	training's quantile: 7.33495	valid_1's quantile: 8.53239
# [10700]	training's quantile: 7.32396	valid_1's quantile: 8.52904
# [10800]	training's quantile: 7.31343	valid_1's quantile: 8.52613
# [10900]	training's quantile: 7.30341	valid_1's quantile: 8.52267
# [11000]	training's quantile: 7.29194	valid_1's quantile: 8.51926
# [11100]	training's quantile: 7.28001	valid_1's quantile: 8.51547
# [11200]	training's quantile: 7.27024	valid_1's quantile: 8.51222
# [11300]	training's quantile: 7.25966	valid_1's quantile: 8.50812
# [11400]	training's quantile: 7.24811	valid_1's quantile: 8.50385
# [11500]	training's quantile: 7.23811	valid_1's quantile: 8.50176
# [11600]	training's quantile: 7.22877	valid_1's quantile: 8.49922
# [11700]	training's quantile: 7.21984	valid_1's quantile: 8.49693
# [11800]	training's quantile: 7.21095	valid_1's quantile: 8.49482
# [11900]	training's quantile: 7.20205	valid_1's quantile: 8.49284
# [12000]	training's quantile: 7.1943	valid_1's quantile: 8.49105
# [12100]	training's quantile: 7.18739	valid_1's quantile: 8.48953
# [12200]	training's quantile: 7.17895	valid_1's quantile: 8.48701
# [12300]	training's quantile: 7.17172	valid_1's quantile: 8.48496
# [12400]	training's quantile: 7.16422	valid_1's quantile: 8.48321
# [12500]	training's quantile: 7.15604	valid_1's quantile: 8.48116
# [12600]	training's quantile: 7.14845	valid_1's quantile: 8.47899
# [12700]	training's quantile: 7.14109	valid_1's quantile: 8.47683
# [12800]	training's quantile: 7.13339	valid_1's quantile: 8.47406
# [12900]	training's quantile: 7.1256	valid_1's quantile: 8.47177
# [13000]	training's quantile: 7.11771	valid_1's quantile: 8.46915
# [13100]	training's quantile: 7.11071	valid_1's quantile: 8.46744
# [13200]	training's quantile: 7.1038	valid_1's quantile: 8.46599
# [13300]	training's quantile: 7.09747	valid_1's quantile: 8.46433
# [13400]	training's quantile: 7.09078	valid_1's quantile: 8.46259
# [13500]	training's quantile: 7.08436	valid_1's quantile: 8.46136
# [13600]	training's quantile: 7.07797	valid_1's quantile: 8.45947
# [13700]	training's quantile: 7.07225	valid_1's quantile: 8.45821
# [13800]	training's quantile: 7.06665	valid_1's quantile: 8.45701
# [13900]	training's quantile: 7.06076	valid_1's quantile: 8.4555
# [14000]	training's quantile: 7.05534	valid_1's quantile: 8.45409
# [14100]	training's quantile: 7.04927	valid_1's quantile: 8.45259
# [14200]	training's quantile: 7.04329	valid_1's quantile: 8.45114
# [14300]	training's quantile: 7.0366	valid_1's quantile: 8.44983
# [14400]	training's quantile: 7.03031	valid_1's quantile: 8.44839
# [14500]	training's quantile: 7.02297	valid_1's quantile: 8.44683
# [14600]	training's quantile: 7.01708	valid_1's quantile: 8.44512
# [14700]	training's quantile: 7.01118	valid_1's quantile: 8.44303
# [14800]	training's quantile: 7.00497	valid_1's quantile: 8.44159
# [14900]	training's quantile: 6.99935	valid_1's quantile: 8.44012
# [15000]	training's quantile: 6.99396	valid_1's quantile: 8.43941
# [15100]	training's quantile: 6.9883	valid_1's quantile: 8.4386
# [15200]	training's quantile: 6.9824	valid_1's quantile: 8.43717
# [15300]	training's quantile: 6.97689	valid_1's quantile: 8.43591
# [15400]	training's quantile: 6.97097	valid_1's quantile: 8.43434
# [15500]	training's quantile: 6.9652	valid_1's quantile: 8.43305
# [15600]	training's quantile: 6.95892	valid_1's quantile: 8.4313
# [15700]	training's quantile: 6.95273	valid_1's quantile: 8.42984
# [15800]	training's quantile: 6.94775	valid_1's quantile: 8.42872
# [15900]	training's quantile: 6.94233	valid_1's quantile: 8.42722
# [16000]	training's quantile: 6.93748	valid_1's quantile: 8.42638
# [16100]	training's quantile: 6.93207	valid_1's quantile: 8.42502
# [16200]	training's quantile: 6.92624	valid_1's quantile: 8.42394
# [16300]	training's quantile: 6.92147	valid_1's quantile: 8.42342
# [16400]	training's quantile: 6.91578	valid_1's quantile: 8.42225
# [16500]	training's quantile: 6.91085	valid_1's quantile: 8.42184
# [16600]	training's quantile: 6.90544	valid_1's quantile: 8.41978
# [16700]	training's quantile: 6.90024	valid_1's quantile: 8.41845
# [16800]	training's quantile: 6.89544	valid_1's quantile: 8.41729
# [16900]	training's quantile: 6.89055	valid_1's quantile: 8.41606
# [17000]	training's quantile: 6.88509	valid_1's quantile: 8.41519
# [17100]	training's quantile: 6.87919	valid_1's quantile: 8.41326
# [17200]	training's quantile: 6.87374	valid_1's quantile: 8.41221
# [17300]	training's quantile: 6.86791	valid_1's quantile: 8.41067
# [17400]	training's quantile: 6.86238	valid_1's quantile: 8.40998
# [17500]	training's quantile: 6.85703	valid_1's quantile: 8.40909
# [17600]	training's quantile: 6.85221	valid_1's quantile: 8.40858
# [17700]	training's quantile: 6.84538	valid_1's quantile: 8.40721
# [17800]	training's quantile: 6.83954	valid_1's quantile: 8.40578
# [17900]	training's quantile: 6.83462	valid_1's quantile: 8.40412
# [18000]	training's quantile: 6.83028	valid_1's quantile: 8.40309
# [18100]	training's quantile: 6.82607	valid_1's quantile: 8.40202
# [18200]	training's quantile: 6.82127	valid_1's quantile: 8.40114
# [18300]	training's quantile: 6.81673	valid_1's quantile: 8.40059
# [18400]	training's quantile: 6.8109	valid_1's quantile: 8.39958
# [18500]	training's quantile: 6.80534	valid_1's quantile: 8.39832
# [18600]	training's quantile: 6.79995	valid_1's quantile: 8.39756
# [18700]	training's quantile: 6.79488	valid_1's quantile: 8.39696
# [18800]	training's quantile: 6.79057	valid_1's quantile: 8.39558
# [18900]	training's quantile: 6.78575	valid_1's quantile: 8.39445
# [19000]	training's quantile: 6.78057	valid_1's quantile: 8.39317
# [19100]	training's quantile: 6.7747	valid_1's quantile: 8.39137
# [19200]	training's quantile: 6.7703	valid_1's quantile: 8.39035
# [19300]	training's quantile: 6.76624	valid_1's quantile: 8.3897
# [19400]	training's quantile: 6.76216	valid_1's quantile: 8.38927
# [19500]	training's quantile: 6.75773	valid_1's quantile: 8.38828
# [19600]	training's quantile: 6.75293	valid_1's quantile: 8.38731
# [19700]	training's quantile: 6.74895	valid_1's quantile: 8.3866
# [19800]	training's quantile: 6.74436	valid_1's quantile: 8.3851
# [19900]	training's quantile: 6.73914	valid_1's quantile: 8.38431
# [20000]	training's quantile: 6.73457	valid_1's quantile: 8.38306
# [20100]	training's quantile: 6.72948	valid_1's quantile: 8.38205
# [20200]	training's quantile: 6.72518	valid_1's quantile: 8.38074
# [20300]	training's quantile: 6.72099	valid_1's quantile: 8.37988
# [20400]	training's quantile: 6.71664	valid_1's quantile: 8.37856
# [20500]	training's quantile: 6.71214	valid_1's quantile: 8.37762
# [20600]	training's quantile: 6.70779	valid_1's quantile: 8.37685
# [20700]	training's quantile: 6.70358	valid_1's quantile: 8.37613
# [20800]	training's quantile: 6.6991	valid_1's quantile: 8.37549
# [20900]	training's quantile: 6.69476	valid_1's quantile: 8.37486
# [21000]	training's quantile: 6.69039	valid_1's quantile: 8.37387
# [21100]	training's quantile: 6.68625	valid_1's quantile: 8.3731
# [21200]	training's quantile: 6.68165	valid_1's quantile: 8.37209
# [21300]	training's quantile: 6.6779	valid_1's quantile: 8.37111
# [21400]	training's quantile: 6.67362	valid_1's quantile: 8.37067
# [21500]	training's quantile: 6.66882	valid_1's quantile: 8.36949
# [21600]	training's quantile: 6.66487	valid_1's quantile: 8.36873
# [21700]	training's quantile: 6.66083	valid_1's quantile: 8.36741
# [21800]	training's quantile: 6.65632	valid_1's quantile: 8.36655
# [21900]	training's quantile: 6.65253	valid_1's quantile: 8.36604
# [22000]	training's quantile: 6.64831	valid_1's quantile: 8.36568
# [22100]	training's quantile: 6.64371	valid_1's quantile: 8.36491
# [22200]	training's quantile: 6.63922	valid_1's quantile: 8.36346
# [22300]	training's quantile: 6.63486	valid_1's quantile: 8.36269
# [22400]	training's quantile: 6.63076	valid_1's quantile: 8.36179
# [22500]	training's quantile: 6.62663	valid_1's quantile: 8.36055
# [22600]	training's quantile: 6.62194	valid_1's quantile: 8.35956
# [22700]	training's quantile: 6.61767	valid_1's quantile: 8.35888
# [22800]	training's quantile: 6.6131	valid_1's quantile: 8.358
# [22900]	training's quantile: 6.60882	valid_1's quantile: 8.35749
# [23000]	training's quantile: 6.60346	valid_1's quantile: 8.35616
# [23100]	training's quantile: 6.59853	valid_1's quantile: 8.35557
# [23200]	training's quantile: 6.59442	valid_1's quantile: 8.355
# [23300]	training's quantile: 6.5901	valid_1's quantile: 8.35414
# [23400]	training's quantile: 6.58591	valid_1's quantile: 8.35348
# [23500]	training's quantile: 6.58185	valid_1's quantile: 8.35321
# [23600]	training's quantile: 6.57813	valid_1's quantile: 8.35223
# [23700]	training's quantile: 6.5742	valid_1's quantile: 8.35163
# [23800]	training's quantile: 6.57008	valid_1's quantile: 8.35063
# [23900]	training's quantile: 6.56605	valid_1's quantile: 8.34961
# [24000]	training's quantile: 6.562	valid_1's quantile: 8.34893
# [24100]	training's quantile: 6.55742	valid_1's quantile: 8.34785
# [24200]	training's quantile: 6.55367	valid_1's quantile: 8.34677
# [24300]	training's quantile: 6.55018	valid_1's quantile: 8.3455
# [24400]	training's quantile: 6.54717	valid_1's quantile: 8.34485
# [24500]	training's quantile: 6.54391	valid_1's quantile: 8.34442
# [24600]	training's quantile: 6.53972	valid_1's quantile: 8.34342
# [24700]	training's quantile: 6.53545	valid_1's quantile: 8.34244
# [24800]	training's quantile: 6.53166	valid_1's quantile: 8.34171
# [24900]	training's quantile: 6.52723	valid_1's quantile: 8.34062
# [25000]	training's quantile: 6.52271	valid_1's quantile: 8.33986
# [25100]	training's quantile: 6.51865	valid_1's quantile: 8.33916
# [25200]	training's quantile: 6.51443	valid_1's quantile: 8.33847
# [25300]	training's quantile: 6.51003	valid_1's quantile: 8.33783
# [25400]	training's quantile: 6.50543	valid_1's quantile: 8.33692
# [25500]	training's quantile: 6.50122	valid_1's quantile: 8.3365
# [25600]	training's quantile: 6.49673	valid_1's quantile: 8.33572
# [25700]	training's quantile: 6.49187	valid_1's quantile: 8.33433
# [25800]	training's quantile: 6.48719	valid_1's quantile: 8.33312
# [25900]	training's quantile: 6.48358	valid_1's quantile: 8.33243
# [26000]	training's quantile: 6.4799	valid_1's quantile: 8.33153
# [26100]	training's quantile: 6.47608	valid_1's quantile: 8.33101
# [26200]	training's quantile: 6.47239	valid_1's quantile: 8.33011
# [26300]	training's quantile: 6.46864	valid_1's quantile: 8.32949
# [26400]	training's quantile: 6.46512	valid_1's quantile: 8.32909
# [26500]	training's quantile: 6.46224	valid_1's quantile: 8.32838
# [26600]	training's quantile: 6.45938	valid_1's quantile: 8.32828
# [26700]	training's quantile: 6.45575	valid_1's quantile: 8.32768
# [26800]	training's quantile: 6.45183	valid_1's quantile: 8.3267
# [26900]	training's quantile: 6.44791	valid_1's quantile: 8.32613
# [27000]	training's quantile: 6.44446	valid_1's quantile: 8.32559
# [27100]	training's quantile: 6.44086	valid_1's quantile: 8.32463
# [27200]	training's quantile: 6.43687	valid_1's quantile: 8.32395
# [27300]	training's quantile: 6.43292	valid_1's quantile: 8.32349
# [27400]	training's quantile: 6.4298	valid_1's quantile: 8.32299
# [27500]	training's quantile: 6.42663	valid_1's quantile: 8.32253
# [27600]	training's quantile: 6.423	valid_1's quantile: 8.32188
# [27700]	training's quantile: 6.42003	valid_1's quantile: 8.32088
# [27800]	training's quantile: 6.417	valid_1's quantile: 8.32065
# [27900]	training's quantile: 6.41386	valid_1's quantile: 8.32029
# [28000]	training's quantile: 6.41082	valid_1's quantile: 8.31982
# [28100]	training's quantile: 6.40695	valid_1's quantile: 8.31886
# [28200]	training's quantile: 6.40406	valid_1's quantile: 8.31777
# [28300]	training's quantile: 6.40124	valid_1's quantile: 8.31744
# [28400]	training's quantile: 6.39809	valid_1's quantile: 8.31684
# [28500]	training's quantile: 6.39534	valid_1's quantile: 8.31663
# Early stopping, best iteration is:
# [28449]	training's quantile: 6.39665	valid_1's quantile: 8.31644
# ----------- 2
# Training until validation scores don't improve for 100 rounds
# [100]	training's quantile: 12.259	valid_1's quantile: 12.5416
# [200]	training's quantile: 10.6841	valid_1's quantile: 11.0336
# [300]	training's quantile: 9.95258	valid_1's quantile: 10.3607
# [400]	training's quantile: 9.59737	valid_1's quantile: 10.0703
# [500]	training's quantile: 9.39362	valid_1's quantile: 9.92551
# [600]	training's quantile: 9.2669	valid_1's quantile: 9.84325
# [700]	training's quantile: 9.17696	valid_1's quantile: 9.78495
# [800]	training's quantile: 9.11101	valid_1's quantile: 9.74286
# [900]	training's quantile: 9.04828	valid_1's quantile: 9.70625
# [1000]	training's quantile: 8.99847	valid_1's quantile: 9.68076
# [1100]	training's quantile: 8.95018	valid_1's quantile: 9.65226
# [1200]	training's quantile: 8.89883	valid_1's quantile: 9.62511
# [1300]	training's quantile: 8.86051	valid_1's quantile: 9.60704
# [1400]	training's quantile: 8.82465	valid_1's quantile: 9.58817
# [1500]	training's quantile: 8.79204	valid_1's quantile: 9.57532
# [1600]	training's quantile: 8.75894	valid_1's quantile: 9.55978
# [1700]	training's quantile: 8.72793	valid_1's quantile: 9.54762
# [1800]	training's quantile: 8.69881	valid_1's quantile: 9.53561
# [1900]	training's quantile: 8.66604	valid_1's quantile: 9.52079
# [2000]	training's quantile: 8.63207	valid_1's quantile: 9.50662
# [2100]	training's quantile: 8.60101	valid_1's quantile: 9.49447
# [2200]	training's quantile: 8.57491	valid_1's quantile: 9.48359
# [2300]	training's quantile: 8.55063	valid_1's quantile: 9.47238
# [2400]	training's quantile: 8.52813	valid_1's quantile: 9.46406
# [2500]	training's quantile: 8.50694	valid_1's quantile: 9.45464
# [2600]	training's quantile: 8.48407	valid_1's quantile: 9.44521
# [2700]	training's quantile: 8.46122	valid_1's quantile: 9.43542
# [2800]	training's quantile: 8.43369	valid_1's quantile: 9.42428
# [2900]	training's quantile: 8.4113	valid_1's quantile: 9.41506
# [3000]	training's quantile: 8.3883	valid_1's quantile: 9.40467
# [3100]	training's quantile: 8.37064	valid_1's quantile: 9.39838
# [3200]	training's quantile: 8.3533	valid_1's quantile: 9.39212
# [3300]	training's quantile: 8.33539	valid_1's quantile: 9.38566
# [3400]	training's quantile: 8.3186	valid_1's quantile: 9.38014
# [3500]	training's quantile: 8.2966	valid_1's quantile: 9.37091
# [3600]	training's quantile: 8.27578	valid_1's quantile: 9.3625
# [3700]	training's quantile: 8.25456	valid_1's quantile: 9.35425
# [3800]	training's quantile: 8.23296	valid_1's quantile: 9.34547
# [3900]	training's quantile: 8.21421	valid_1's quantile: 9.33905
# [4000]	training's quantile: 8.19322	valid_1's quantile: 9.32992
# [4100]	training's quantile: 8.17083	valid_1's quantile: 9.32099
# [4200]	training's quantile: 8.15262	valid_1's quantile: 9.31371
# [4300]	training's quantile: 8.13329	valid_1's quantile: 9.30562
# [4400]	training's quantile: 8.11416	valid_1's quantile: 9.29856
# [4500]	training's quantile: 8.09683	valid_1's quantile: 9.2938
# [4600]	training's quantile: 8.07818	valid_1's quantile: 9.2862
# [4700]	training's quantile: 8.06065	valid_1's quantile: 9.28091
# [4800]	training's quantile: 8.04314	valid_1's quantile: 9.27527
# [4900]	training's quantile: 8.02692	valid_1's quantile: 9.26816
# [5000]	training's quantile: 8.01042	valid_1's quantile: 9.26153
# [5100]	training's quantile: 7.99352	valid_1's quantile: 9.25544
# [5200]	training's quantile: 7.97617	valid_1's quantile: 9.2477
# [5300]	training's quantile: 7.95873	valid_1's quantile: 9.24185
# [5400]	training's quantile: 7.94313	valid_1's quantile: 9.2366
# [5500]	training's quantile: 7.9261	valid_1's quantile: 9.22917
# [5600]	training's quantile: 7.91131	valid_1's quantile: 9.22362
# [5700]	training's quantile: 7.8941	valid_1's quantile: 9.21746
# [5800]	training's quantile: 7.87691	valid_1's quantile: 9.21102
# [5900]	training's quantile: 7.8595	valid_1's quantile: 9.20482
# [6000]	training's quantile: 7.84579	valid_1's quantile: 9.19981
# [6100]	training's quantile: 7.83143	valid_1's quantile: 9.19471
# [6200]	training's quantile: 7.81948	valid_1's quantile: 9.19093
# [6300]	training's quantile: 7.80703	valid_1's quantile: 9.18637
# [6400]	training's quantile: 7.79404	valid_1's quantile: 9.18069
# [6500]	training's quantile: 7.7802	valid_1's quantile: 9.17522
# [6600]	training's quantile: 7.7674	valid_1's quantile: 9.1713
# [6700]	training's quantile: 7.75366	valid_1's quantile: 9.16677
# [6800]	training's quantile: 7.74093	valid_1's quantile: 9.16211
# [6900]	training's quantile: 7.72974	valid_1's quantile: 9.15831
# [7000]	training's quantile: 7.71702	valid_1's quantile: 9.15423
# [7100]	training's quantile: 7.70196	valid_1's quantile: 9.14894
# [7200]	training's quantile: 7.68759	valid_1's quantile: 9.14379
# [7300]	training's quantile: 7.67586	valid_1's quantile: 9.13859
# [7400]	training's quantile: 7.6653	valid_1's quantile: 9.13428
# [7500]	training's quantile: 7.65419	valid_1's quantile: 9.13035
# [7600]	training's quantile: 7.6433	valid_1's quantile: 9.12649
# [7700]	training's quantile: 7.63253	valid_1's quantile: 9.12188
# [7800]	training's quantile: 7.6227	valid_1's quantile: 9.11837
# [7900]	training's quantile: 7.61222	valid_1's quantile: 9.1142
# [8000]	training's quantile: 7.60261	valid_1's quantile: 9.11095
# [8100]	training's quantile: 7.59286	valid_1's quantile: 9.10875
# [8200]	training's quantile: 7.58221	valid_1's quantile: 9.10547
# [8300]	training's quantile: 7.57283	valid_1's quantile: 9.10312
# [8400]	training's quantile: 7.56215	valid_1's quantile: 9.09951
# [8500]	training's quantile: 7.55032	valid_1's quantile: 9.09601
# [8600]	training's quantile: 7.53763	valid_1's quantile: 9.0917
# [8700]	training's quantile: 7.52526	valid_1's quantile: 9.08734
# [8800]	training's quantile: 7.51441	valid_1's quantile: 9.08438
# [8900]	training's quantile: 7.50381	valid_1's quantile: 9.08171
# [9000]	training's quantile: 7.49266	valid_1's quantile: 9.07704
# [9100]	training's quantile: 7.48154	valid_1's quantile: 9.07369
# [9200]	training's quantile: 7.47054	valid_1's quantile: 9.07068
# [9300]	training's quantile: 7.46155	valid_1's quantile: 9.0679
# [9400]	training's quantile: 7.45265	valid_1's quantile: 9.06455
# [9500]	training's quantile: 7.4433	valid_1's quantile: 9.06203
# [9600]	training's quantile: 7.43284	valid_1's quantile: 9.05823
# [9700]	training's quantile: 7.42347	valid_1's quantile: 9.05556
# [9800]	training's quantile: 7.41352	valid_1's quantile: 9.05253
# [9900]	training's quantile: 7.40332	valid_1's quantile: 9.04897
# [10000]	training's quantile: 7.39457	valid_1's quantile: 9.04587
# [10100]	training's quantile: 7.38535	valid_1's quantile: 9.04322
# [10200]	training's quantile: 7.3758	valid_1's quantile: 9.04017
# [10300]	training's quantile: 7.36655	valid_1's quantile: 9.03726
# [10400]	training's quantile: 7.35702	valid_1's quantile: 9.03382
# [10500]	training's quantile: 7.34841	valid_1's quantile: 9.03212
# [10600]	training's quantile: 7.34034	valid_1's quantile: 9.02994
# [10700]	training's quantile: 7.32937	valid_1's quantile: 9.02675
# [10800]	training's quantile: 7.31981	valid_1's quantile: 9.02376
# [10900]	training's quantile: 7.31177	valid_1's quantile: 9.02126
# [11000]	training's quantile: 7.30281	valid_1's quantile: 9.01882
# [11100]	training's quantile: 7.29296	valid_1's quantile: 9.01567
# [11200]	training's quantile: 7.28369	valid_1's quantile: 9.01252
# [11300]	training's quantile: 7.27489	valid_1's quantile: 9.01049
# [11400]	training's quantile: 7.2669	valid_1's quantile: 9.0088
# [11500]	training's quantile: 7.25796	valid_1's quantile: 9.00663
# [11600]	training's quantile: 7.24984	valid_1's quantile: 9.00487
# [11700]	training's quantile: 7.24177	valid_1's quantile: 9.00254
# [11800]	training's quantile: 7.23277	valid_1's quantile: 8.99976
# [11900]	training's quantile: 7.22443	valid_1's quantile: 8.99717
# [12000]	training's quantile: 7.21764	valid_1's quantile: 8.99531
# [12100]	training's quantile: 7.20988	valid_1's quantile: 8.99315
# [12200]	training's quantile: 7.20268	valid_1's quantile: 8.99179
# [12300]	training's quantile: 7.19454	valid_1's quantile: 8.98786
# [12400]	training's quantile: 7.18707	valid_1's quantile: 8.98566
# [12500]	training's quantile: 7.17911	valid_1's quantile: 8.98361
# [12600]	training's quantile: 7.17265	valid_1's quantile: 8.98194
# [12700]	training's quantile: 7.16413	valid_1's quantile: 8.97914
# [12800]	training's quantile: 7.15676	valid_1's quantile: 8.97706
# [12900]	training's quantile: 7.14883	valid_1's quantile: 8.97481
# ...
# [8000]	training's quantile: 0.259238	valid_1's quantile: 0.304087
# [8100]	training's quantile: 0.258672	valid_1's quantile: 0.303867
# [8200]	training's quantile: 0.258091	valid_1's quantile: 0.303666
# [8300]	training's quantile: 0.257534	valid_1's quantile: 0.303476
# [8400]	training's quantile: 0.256969	valid_1's quantile: 0.303304
# [8500]	training's quantile: 0.256437	valid_1's quantile: 0.303136
# [8600]	training's quantile: 0.255872	valid_1's quantile: 0.302926
# [8700]	training's quantile: 0.255302	valid_1's quantile: 0.302708
# [8800]	training's quantile: 0.254694	valid_1's quantile: 0.302497
# [8900]	training's quantile: 0.254108	valid_1's quantile: 0.302285
# [9000]	training's quantile: 0.253574	valid_1's quantile: 0.302063
# [9100]	training's quantile: 0.252953	valid_1's quantile: 0.301853
# [9200]	training's quantile: 0.252381	valid_1's quantile: 0.30164
# [9300]	training's quantile: 0.251809	valid_1's quantile: 0.30145
# [9400]	training's quantile: 0.251193	valid_1's quantile: 0.301192
# [9500]	training's quantile: 0.25061	valid_1's quantile: 0.300999
# [9600]	training's quantile: 0.25003	valid_1's quantile: 0.300775
# [9700]	training's quantile: 0.249484	valid_1's quantile: 0.300554
# [9800]	training's quantile: 0.248926	valid_1's quantile: 0.300339
# [9900]	training's quantile: 0.248399	valid_1's quantile: 0.300162
# [10000]	training's quantile: 0.247876	valid_1's quantile: 0.299976
# [10100]	training's quantile: 0.247311	valid_1's quantile: 0.299817
# [10200]	training's quantile: 0.246754	valid_1's quantile: 0.299577
# [10300]	training's quantile: 0.246209	valid_1's quantile: 0.299394
# [10400]	training's quantile: 0.245674	valid_1's quantile: 0.299194
# [10500]	training's quantile: 0.245219	valid_1's quantile: 0.299042
# [10600]	training's quantile: 0.244817	valid_1's quantile: 0.298926
# [10700]	training's quantile: 0.244361	valid_1's quantile: 0.298756
# [10800]	training's quantile: 0.24389	valid_1's quantile: 0.298619
# [10900]	training's quantile: 0.243436	valid_1's quantile: 0.298509
# [11000]	training's quantile: 0.242944	valid_1's quantile: 0.298304
# [11100]	training's quantile: 0.242493	valid_1's quantile: 0.298136
# [11200]	training's quantile: 0.242081	valid_1's quantile: 0.298033
# [11300]	training's quantile: 0.241647	valid_1's quantile: 0.2979
# [11400]	training's quantile: 0.241215	valid_1's quantile: 0.297762
# [11500]	training's quantile: 0.240772	valid_1's quantile: 0.297606
# [11600]	training's quantile: 0.240349	valid_1's quantile: 0.297489
# [11700]	training's quantile: 0.239929	valid_1's quantile: 0.297388
# [11800]	training's quantile: 0.239529	valid_1's quantile: 0.297265
# [11900]	training's quantile: 0.239164	valid_1's quantile: 0.297184
# [12000]	training's quantile: 0.238781	valid_1's quantile: 0.297081
# [12100]	training's quantile: 0.238402	valid_1's quantile: 0.296973
# [12200]	training's quantile: 0.238012	valid_1's quantile: 0.296837
# [12300]	training's quantile: 0.237642	valid_1's quantile: 0.29678
# [12400]	training's quantile: 0.237274	valid_1's quantile: 0.296679
# [12500]	training's quantile: 0.236897	valid_1's quantile: 0.296593
# [12600]	training's quantile: 0.236549	valid_1's quantile: 0.296528
# [12700]	training's quantile: 0.236193	valid_1's quantile: 0.29646
# [12800]	training's quantile: 0.235829	valid_1's quantile: 0.296367
# [12900]	training's quantile: 0.235469	valid_1's quantile: 0.296276
# [13000]	training's quantile: 0.235116	valid_1's quantile: 0.296204
# [13100]	training's quantile: 0.234762	valid_1's quantile: 0.296133
# [13200]	training's quantile: 0.234415	valid_1's quantile: 0.296063
# [13300]	training's quantile: 0.234062	valid_1's quantile: 0.295981
# [13400]	training's quantile: 0.233721	valid_1's quantile: 0.295914
# [13500]	training's quantile: 0.233384	valid_1's quantile: 0.295839
# [13600]	training's quantile: 0.233045	valid_1's quantile: 0.295779
# [13700]	training's quantile: 0.232717	valid_1's quantile: 0.295722
# [13800]	training's quantile: 0.232357	valid_1's quantile: 0.295652
# [13900]	training's quantile: 0.231994	valid_1's quantile: 0.295531
# [14000]	training's quantile: 0.231601	valid_1's quantile: 0.295391
# [14100]	training's quantile: 0.231234	valid_1's quantile: 0.295282
# [14200]	training's quantile: 0.230869	valid_1's quantile: 0.295175
# [14300]	training's quantile: 0.230524	valid_1's quantile: 0.295091
# [14400]	training's quantile: 0.230184	valid_1's quantile: 0.294987
# [14500]	training's quantile: 0.22985	valid_1's quantile: 0.294909
# [14600]	training's quantile: 0.229504	valid_1's quantile: 0.294817
# [14700]	training's quantile: 0.229154	valid_1's quantile: 0.2947
# [14800]	training's quantile: 0.228811	valid_1's quantile: 0.29459
# [14900]	training's quantile: 0.228463	valid_1's quantile: 0.294469
# [15000]	training's quantile: 0.228126	valid_1's quantile: 0.29434
# [15100]	training's quantile: 0.22777	valid_1's quantile: 0.294236
# [15200]	training's quantile: 0.227418	valid_1's quantile: 0.294144
# [15300]	training's quantile: 0.227093	valid_1's quantile: 0.294051
# [15400]	training's quantile: 0.226776	valid_1's quantile: 0.293948
# [15500]	training's quantile: 0.226463	valid_1's quantile: 0.293844
# [15600]	training's quantile: 0.226146	valid_1's quantile: 0.29375
# [15700]	training's quantile: 0.225886	valid_1's quantile: 0.2937
# [15800]	training's quantile: 0.225608	valid_1's quantile: 0.293659
# [15900]	training's quantile: 0.22533	valid_1's quantile: 0.293613
# [16000]	training's quantile: 0.225009	valid_1's quantile: 0.29353
# [16100]	training's quantile: 0.224719	valid_1's quantile: 0.293479
# [16200]	training's quantile: 0.224437	valid_1's quantile: 0.293437
# [16300]	training's quantile: 0.224079	valid_1's quantile: 0.293339
# [16400]	training's quantile: 0.223715	valid_1's quantile: 0.293217
# [16500]	training's quantile: 0.223387	valid_1's quantile: 0.293133
# [16600]	training's quantile: 0.223088	valid_1's quantile: 0.293034
# [16700]	training's quantile: 0.222766	valid_1's quantile: 0.292963
# [16800]	training's quantile: 0.222506	valid_1's quantile: 0.292925
# [16900]	training's quantile: 0.222221	valid_1's quantile: 0.292857
# [17000]	training's quantile: 0.221937	valid_1's quantile: 0.292809
# [17100]	training's quantile: 0.22163	valid_1's quantile: 0.292753
# [17200]	training's quantile: 0.221318	valid_1's quantile: 0.292664
# [17300]	training's quantile: 0.221015	valid_1's quantile: 0.29257
# [17400]	training's quantile: 0.2207	valid_1's quantile: 0.292472
# [17500]	training's quantile: 0.220405	valid_1's quantile: 0.292409
# [17600]	training's quantile: 0.220143	valid_1's quantile: 0.292362
# [17700]	training's quantile: 0.219888	valid_1's quantile: 0.292296
# [17800]	training's quantile: 0.219643	valid_1's quantile: 0.292247
# [17900]	training's quantile: 0.219395	valid_1's quantile: 0.292198
# [18000]	training's quantile: 0.219115	valid_1's quantile: 0.292105
# [18100]	training's quantile: 0.218849	valid_1's quantile: 0.292035
# [18200]	training's quantile: 0.218598	valid_1's quantile: 0.291989
# [18300]	training's quantile: 0.218333	valid_1's quantile: 0.291919
# [18400]	training's quantile: 0.218101	valid_1's quantile: 0.291899
# [18500]	training's quantile: 0.217875	valid_1's quantile: 0.291867
# [18600]	training's quantile: 0.217626	valid_1's quantile: 0.291812
# [18700]	training's quantile: 0.217381	valid_1's quantile: 0.291768
# [18800]	training's quantile: 0.217147	valid_1's quantile: 0.291753
# [18900]	training's quantile: 0.216898	valid_1's quantile: 0.291731
# [19000]	training's quantile: 0.216617	valid_1's quantile: 0.291667
# [19100]	training's quantile: 0.216322	valid_1's quantile: 0.291603
# [19200]	training's quantile: 0.216059	valid_1's quantile: 0.291534
# [19300]	training's quantile: 0.215825	valid_1's quantile: 0.2915
# [19400]	training's quantile: 0.215577	valid_1's quantile: 0.291423
# [19500]	training's quantile: 0.215327	valid_1's quantile: 0.291384
# [19600]	training's quantile: 0.215075	valid_1's quantile: 0.291328
# [19700]	training's quantile: 0.214818	valid_1's quantile: 0.291286
# [19800]	training's quantile: 0.214548	valid_1's quantile: 0.291201
# [19900]	training's quantile: 0.214299	valid_1's quantile: 0.291153
# [20000]	training's quantile: 0.214053	valid_1's quantile: 0.291107
# [20100]	training's quantile: 0.213737	valid_1's quantile: 0.291012
# [20200]	training's quantile: 0.213492	valid_1's quantile: 0.290964
# [20300]	training's quantile: 0.213256	valid_1's quantile: 0.290898
# [20400]	training's quantile: 0.212994	valid_1's quantile: 0.290841
# [20500]	training's quantile: 0.212686	valid_1's quantile: 0.290749
# [20600]	training's quantile: 0.212456	valid_1's quantile: 0.290696
# [20700]	training's quantile: 0.212238	valid_1's quantile: 0.290655
# [20800]	training's quantile: 0.212014	valid_1's quantile: 0.290618
# [20900]	training's quantile: 0.211782	valid_1's quantile: 0.29057
# [21000]	training's quantile: 0.211563	valid_1's quantile: 0.290536
# [21100]	training's quantile: 0.211338	valid_1's quantile: 0.290464
# [21200]	training's quantile: 0.211129	valid_1's quantile: 0.290444
# [21300]	training's quantile: 0.210932	valid_1's quantile: 0.290417
# [21400]	training's quantile: 0.210701	valid_1's quantile: 0.290375
# [21500]	training's quantile: 0.210463	valid_1's quantile: 0.290328
# [21600]	training's quantile: 0.210251	valid_1's quantile: 0.290299
# [21700]	training's quantile: 0.210049	valid_1's quantile: 0.290275
# [21800]	training's quantile: 0.209832	valid_1's quantile: 0.290227
# [21900]	training's quantile: 0.209608	valid_1's quantile: 0.290169
# [22000]	training's quantile: 0.209397	valid_1's quantile: 0.290132
# [22100]	training's quantile: 0.209204	valid_1's quantile: 0.290098
# [22200]	training's quantile: 0.209016	valid_1's quantile: 0.290076
# [22300]	training's quantile: 0.208824	valid_1's quantile: 0.290045
# [22400]	training's quantile: 0.208629	valid_1's quantile: 0.290022
# [22500]	training's quantile: 0.208414	valid_1's quantile: 0.289975
# [22600]	training's quantile: 0.208188	valid_1's quantile: 0.289922
# [22700]	training's quantile: 0.207995	valid_1's quantile: 0.289905
# [22800]	training's quantile: 0.207794	valid_1's quantile: 0.289866
# [22900]	training's quantile: 0.207584	valid_1's quantile: 0.2898
# [23000]	training's quantile: 0.207368	valid_1's quantile: 0.289741
# [23100]	training's quantile: 0.207174	valid_1's quantile: 0.289717
# [23200]	training's quantile: 0.206987	valid_1's quantile: 0.289692
# [23300]	training's quantile: 0.206799	valid_1's quantile: 0.289642
# [23400]	training's quantile: 0.206603	valid_1's quantile: 0.289622
# [23500]	training's quantile: 0.206364	valid_1's quantile: 0.289554
# [23600]	training's quantile: 0.20617	valid_1's quantile: 0.289506
# [23700]	training's quantile: 0.205957	valid_1's quantile: 0.289452
# [23800]	training's quantile: 0.205749	valid_1's quantile: 0.289407
# [23900]	training's quantile: 0.20555	valid_1's quantile: 0.289376
# [24000]	training's quantile: 0.205342	valid_1's quantile: 0.289335
# [24100]	training's quantile: 0.20513	valid_1's quantile: 0.289281
# [24200]	training's quantile: 0.204934	valid_1's quantile: 0.289254
# [24300]	training's quantile: 0.204741	valid_1's quantile: 0.28923
# [24400]	training's quantile: 0.204541	valid_1's quantile: 0.289187
# [24500]	training's quantile: 0.204351	valid_1's quantile: 0.289152
# [24600]	training's quantile: 0.204135	valid_1's quantile: 0.289085
# [24700]	training's quantile: 0.203922	valid_1's quantile: 0.289046
# [24800]	training's quantile: 0.203707	valid_1's quantile: 0.288983
# [24900]	training's quantile: 0.203506	valid_1's quantile: 0.288939
# [25000]	training's quantile: 0.20331	valid_1's quantile: 0.288885
# [25100]	training's quantile: 0.203139	valid_1's quantile: 0.288868
# [25200]	training's quantile: 0.202962	valid_1's quantile: 0.288838
# [25300]	training's quantile: 0.20277	valid_1's quantile: 0.28878
# [25400]	training's quantile: 0.202587	valid_1's quantile: 0.288757
# [25500]	training's quantile: 0.202403	valid_1's quantile: 0.28874
# [25600]	training's quantile: 0.202205	valid_1's quantile: 0.288687
# [25700]	training's quantile: 0.202021	valid_1's quantile: 0.288641
# [25800]	training's quantile: 0.201846	valid_1's quantile: 0.288617
# [25900]	training's quantile: 0.201681	valid_1's quantile: 0.288596
# [26000]	training's quantile: 0.201511	valid_1's quantile: 0.288571
# [26100]	training's quantile: 0.201349	valid_1's quantile: 0.288554
# [26200]	training's quantile: 0.201171	valid_1's quantile: 0.288512
# [26300]	training's quantile: 0.200999	valid_1's quantile: 0.288474
# [26400]	training's quantile: 0.200824	valid_1's quantile: 0.28845
# [26500]	training's quantile: 0.200655	valid_1's quantile: 0.288422
# [26600]	training's quantile: 0.200472	valid_1's quantile: 0.288388
# [26700]	training's quantile: 0.200292	valid_1's quantile: 0.28835
# [26800]	training's quantile: 0.200131	valid_1's quantile: 0.28833
# [26900]	training's quantile: 0.19998	valid_1's quantile: 0.288308
# [27000]	training's quantile: 0.199824	valid_1's quantile: 0.288302
# [27100]	training's quantile: 0.19967	valid_1's quantile: 0.288282
# [27200]	training's quantile: 0.199509	valid_1's quantile: 0.288249
# [27300]	training's quantile: 0.199337	valid_1's quantile: 0.288194
# [27400]	training's quantile: 0.199182	valid_1's quantile: 0.28816
# [27500]	training's quantile: 0.199009	valid_1's quantile: 0.288118
# [27600]	training's quantile: 0.198847	valid_1's quantile: 0.288084
# [27700]	training's quantile: 0.1987	valid_1's quantile: 0.288072
# [27800]	training's quantile: 0.198547	valid_1's quantile: 0.288065
# [27900]	training's quantile: 0.198381	valid_1's quantile: 0.288035
# [28000]	training's quantile: 0.19823	valid_1's quantile: 0.288023
# [28100]	training's quantile: 0.198066	valid_1's quantile: 0.287988
# [28200]	training's quantile: 0.197902	valid_1's quantile: 0.28795
# [28300]	training's quantile: 0.197739	valid_1's quantile: 0.28793
# [28400]	training's quantile: 0.197582	valid_1's quantile: 0.287897
# [28500]	training's quantile: 0.197421	valid_1's quantile: 0.28787
# [28600]	training's quantile: 0.197272	valid_1's quantile: 0.28785
# [28700]	training's quantile: 0.197121	valid_1's quantile: 0.287826
# [28800]	training's quantile: 0.196972	valid_1's quantile: 0.287798
# [28900]	training's quantile: 0.196828	valid_1's quantile: 0.287778
# [29000]	training's quantile: 0.19667	valid_1's quantile: 0.287746
# [29100]	training's quantile: 0.196528	valid_1's quantile: 0.287735
# [29200]	training's quantile: 0.196376	valid_1's quantile: 0.287713
# [29300]	training's quantile: 0.196234	valid_1's quantile: 0.2877
# [29400]	training's quantile: 0.196083	valid_1's quantile: 0.287686
# [29500]	training's quantile: 0.195921	valid_1's quantile: 0.287641
# [29600]	training's quantile: 0.195785	valid_1's quantile: 0.287627
# [29700]	training's quantile: 0.195629	valid_1's quantile: 0.287602
# [29800]	training's quantile: 0.195491	valid_1's quantile: 0.287585
# [29900]	training's quantile: 0.195342	valid_1's quantile: 0.287558
# [30000]	training's quantile: 0.195191	valid_1's quantile: 0.287522
# [30100]	training's quantile: 0.195061	valid_1's quantile: 0.287512
# [30200]	training's quantile: 0.194924	valid_1's quantile: 0.287493
# [30300]	training's quantile: 0.194785	valid_1's quantile: 0.287471
# [30400]	training's quantile: 0.194644	valid_1's quantile: 0.287446
# [30500]	training's quantile: 0.194501	valid_1's quantile: 0.287421
# [30600]	training's quantile: 0.194368	valid_1's quantile: 0.287417
# [30700]	training's quantile: 0.194233	valid_1's quantile: 0.287387
# [30800]	training's quantile: 0.19409	valid_1's quantile: 0.287371
# [30900]	training's quantile: 0.193942	valid_1's quantile: 0.287349
# [31000]	training's quantile: 0.193798	valid_1's quantile: 0.28733
# [31100]	training's quantile: 0.193653	valid_1's quantile: 0.287292
# [31200]	training's quantile: 0.19352	valid_1's quantile: 0.28727
# [31300]	training's quantile: 0.193393	valid_1's quantile: 0.287257
# [31400]	training's quantile: 0.193265	valid_1's quantile: 0.287251
# [31500]	training's quantile: 0.193135	valid_1's quantile: 0.28725
# [31600]	training's quantile: 0.193011	valid_1's quantile: 0.28723
# [31700]	training's quantile: 0.192887	valid_1's quantile: 0.287219
# Early stopping, best iteration is:
# [31654]	training's quantile: 0.192939	valid_1's quantile: 0.287215

# %%
# train_oof = reduce(lambda x,y: pd.merge(x,y,on='ID', how='outer'), train_oof.values())
test_pred = reduce(lambda x,y: pd.merge(x,y,on='ID', how='outer'), test_pred.values())
# train_oof.shape
test_pred.shape

score_str = 'potato_90_15_time'

# %%
if not os.path.exists("result"):
    os.makedirs("result")
# train_oof.to_csv(os.path.join("result", f'lgb_oof_{score_str}.csv'), index=False)
test_pred.to_csv(os.path.join("result", f'{score_str}.csv'), index=False)
